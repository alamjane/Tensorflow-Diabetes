# %%
import pandas as pd

# %%
diabetes = pd.read_csv('Downloads\diabetes.csv')

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
cols_to_norm = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction',]

# %%
diabetes[cols_to_norm]=diabetes[cols_to_norm].apply(lambda x: (x - x.min())/(x.max()-x.min()))

# %%
diabetes.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                  0.234415   50        1
# 1                  0.116567   31        0
# 2                  0.253629   32        1
# 3                  0.038002   21        0
# 4                  0.943638   33        1

# %%
import tensorflow as tf

# %%
num_preg = tf.feature_column.numeric_column('Pregnancies')
plasma_gluc = tf.feature_column.numeric_column('Glucose')
dias_press = tf.feature_column.numeric_column('BloodPressure')
skin_thic = tf.feature_column.numeric_column('SkinThickness')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('DiabetesPedigreeFunction')
age = tf.feature_column.numeric_column('Age')

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])

# %%
#assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group',hash_bucket_size=10)

# %%
import matplotlib.pyplot as plt

# %%
diabetes['Age'].hist(bins=20)

# %%
age_bucket = tf.feature_column.bucketized_column(age,boundaries=[20,30,40,50,60,70,80])

# %%
feat_cols = [num_preg,plasma_gluc,dias_press,skin_thic,insulin,bmi,diabetes_pedigree,age_bucket,assigned_group]

# %%
#Train Test Split

# %%
x_data = diabetes.drop('Outcome', axis=1) 
x_data.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#    DiabetesPedigreeFunction  Age
# 0                  0.234415   50
# 1                  0.116567   31
# 2                  0.253629   32
# 3                  0.038002   21
# 4                  0.943638   33

# %%
labels = diabetes['Outcome']
labels.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_data, labels, test_size=0.3, random_state=101)

# %%
x_train.head()
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 711     0.294118  0.633166       0.639344       0.272727  0.026005  0.441133
# 58      0.000000  0.733668       0.672131       0.000000  0.000000  0.603577
# 216     0.294118  0.547739       0.508197       0.414141  0.152482  0.533532
# 168     0.235294  0.552764       0.540984       0.000000  0.000000  0.475410
# 658     0.647059  0.638191       0.868852       0.000000  0.000000  0.581222
#
#      DiabetesPedigreeFunction  Age
# 711                  0.154142   40
# 58                   0.727156   44
# 216                  0.186166   25
# 168                  0.167805   29
# 658                  0.047822   51

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=x_train,y=y_train, batch_size=10,num_epochs=1000,shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\JANEAL~1\AppData\Local\Temp\tmpnyqfasd3
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\JANEAL~1\\AppData\\Local\\Temp\\tmpnyqfasd3', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000000985770BF88>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func, steps=1000)
# Out:
# WARNING:tensorflow:From C:\New folder\envs\tensorflow\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From C:\New folder\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From C:\New folder\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From C:\New folder\envs\tensorflow\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py:305: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From C:\New folder\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\New folder\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\embedding_ops.py:802: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\New folder\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py:308: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From C:\New folder\envs\tensorflow\lib\site-packages\tensorflow_core\python\training\monitored_session.py:882: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\JANEAL~1\AppData\Local\Temp\tmpnyqfasd3\model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 47.5453
# INFO:tensorflow:loss = 3.4715188, step = 101 (2.106 sec)
# INFO:tensorflow:global_step/sec: 118.259
# INFO:tensorflow:loss = 5.1455584, step = 201 (0.845 sec)
# INFO:tensorflow:global_step/sec: 115.793
# INFO:tensorflow:loss = 4.232306, step = 301 (0.863 sec)
# INFO:tensorflow:global_step/sec: 126.014
# INFO:tensorflow:loss = 4.4763975, step = 401 (0.795 sec)
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 431 vs previous value: 431. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# INFO:tensorflow:global_step/sec: 115.792
# INFO:tensorflow:loss = 6.377227, step = 501 (0.863 sec)
# INFO:tensorflow:global_step/sec: 117.15
# INFO:tensorflow:loss = 3.0521822, step = 601 (0.858 sec)
# INFO:tensorflow:global_step/sec: 122.308
# INFO:tensorflow:loss = 6.3888326, step = 701 (0.821 sec)
# INFO:tensorflow:global_step/sec: 126.657
# INFO:tensorflow:loss = 4.986044, step = 801 (0.795 sec)
# INFO:tensorflow:global_step/sec: 116.196
# INFO:tensorflow:loss = 6.1165276, step = 901 (0.851 sec)
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 918 vs previous value: 918. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\JANEAL~1\AppData\Local\Temp\tmpnyqfasd3\model.ckpt.
# INFO:tensorflow:Loss for final step: 9.057957.

# %%
#Eval the model
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=x_test,y=y_test,batch_size=10,num_epochs=1,
                                                      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From C:\New folder\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:2026: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-11-30T13:33:39Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\JANEAL~1\AppData\Local\Temp\tmpnyqfasd3\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-11-30-13:33:43
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.74458873, accuracy_baseline = 0.64935064, auc = 0.79860085, auc_precision_recall = 0.64582384, average_loss = 0.5267842, global_step = 1000, label/mean = 0.35064936, loss = 5.0702977, precision = 0.6666667, prediction/mean = 0.36350664, recall = 0.54320985
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\JANEAL~1\AppData\Local\Temp\tmpnyqfasd3\model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.74458873,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.79860085,
#  'auc_precision_recall': 0.64582384,
#  'average_loss': 0.5267842,
#  'label/mean': 0.35064936,
#  'loss': 5.0702977,
#  'precision': 0.6666667,
#  'prediction/mean': 0.36350664,
#  'recall': 0.54320985,
#  'global_step': 1000}

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=x_test,batch_size=10,num_epochs=1,shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
my_pred = list(predictions)
my_pred
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\JANEAL~1\AppData\Local\Temp\tmpnyqfasd3\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.01556349], dtype=float32),
#   'logistic': array([0.5038908], dtype=float32),
#   'probabilities': array([0.49610922, 0.5038908 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4951855], dtype=float32),
#   'logistic': array([0.6213272], dtype=float32),
#   'probabilities': array([0.37867272, 0.6213272 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.45414203], dtype=float32),
#   'logistic': array([0.3883764], dtype=float32),
#   'probabilities': array([0.61162364, 0.3883764 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.77568597], dtype=float32),
#   'logistic': array([0.31525043], dtype=float32),
#   'probabilities': array([0.6847496, 0.3152504], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8355447], dtype=float32),
#   'logistic': array([0.13757905], dtype=float32),
#   'probabilities': array([0.862421  , 0.13757905], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6612828], dtype=float32),
#   'logistic': array([0.65954846], dtype=float32),
#   'probabilities': array([0.34045154, 0.6595485 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.39053714], dtype=float32),
#   'logistic': array([0.596412], dtype=float32),
#   'probabilities': array([0.40358803, 0.596412  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6664724], dtype=float32),
#   'logistic': array([0.33928722], dtype=float32),
#   'probabilities': array([0.6607128, 0.3392872], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1590474], dtype=float32),
#   'logistic': array([0.23884043], dtype=float32),
#   'probabilities': array([0.7611596, 0.2388404], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2857219], dtype=float32),
#   'logistic': array([0.21657781], dtype=float32),
#   'probabilities': array([0.78342223, 0.2165778 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.734637], dtype=float32),
#   'logistic': array([0.14999539], dtype=float32),
#   'probabilities': array([0.8500047 , 0.14999542], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7310483], dtype=float32),
#   'logistic': array([0.15045351], dtype=float32),
#   'probabilities': array([0.8495465 , 0.15045351], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8813127], dtype=float32),
#   'logistic': array([0.2929058], dtype=float32),
#   'probabilities': array([0.70709413, 0.29290578], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.22199523], dtype=float32),
#   'logistic': array([0.555272], dtype=float32),
#   'probabilities': array([0.444728  , 0.55527204], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4137076], dtype=float32),
#   'logistic': array([0.19564995], dtype=float32),
#   'probabilities': array([0.80435014, 0.19564994], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.61621857], dtype=float32),
#   'logistic': array([0.35064197], dtype=float32),
#   'probabilities': array([0.64935803, 0.35064194], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.47485113], dtype=float32),
#   'logistic': array([0.3834687], dtype=float32),
#   'probabilities': array([0.6165313 , 0.38346866], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7793127], dtype=float32),
#   'logistic': array([0.14438802], dtype=float32),
#   'probabilities': array([0.855612, 0.144388], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.563692], dtype=float32),
#   'logistic': array([0.36269364], dtype=float32),
#   'probabilities': array([0.6373064 , 0.36269364], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8033406], dtype=float32),
#   'logistic': array([0.1414449], dtype=float32),
#   'probabilities': array([0.85855514, 0.1414449 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.241783], dtype=float32),
#   'logistic': array([0.2241258], dtype=float32),
#   'probabilities': array([0.7758743 , 0.22412577], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8853251], dtype=float32),
#   'logistic': array([0.2920755], dtype=float32),
#   'probabilities': array([0.7079245 , 0.29207546], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5705259], dtype=float32),
#   'logistic': array([0.63888454], dtype=float32),
#   'probabilities': array([0.36111546, 0.63888454], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3933275], dtype=float32),
#   'logistic': array([0.19887704], dtype=float32),
#   'probabilities': array([0.8011229 , 0.19887707], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4048475], dtype=float32),
#   'logistic': array([0.19704804], dtype=float32),
#   'probabilities': array([0.80295205, 0.19704802], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1628959], dtype=float32),
#   'logistic': array([0.7618585], dtype=float32),
#   'probabilities': array([0.23814146, 0.7618586 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4861912], dtype=float32),
#   'logistic': array([0.18449411], dtype=float32),
#   'probabilities': array([0.815506 , 0.1844941], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7411102], dtype=float32),
#   'logistic': array([0.32276142], dtype=float32),
#   'probabilities': array([0.6772386 , 0.32276142], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9677575], dtype=float32),
#   'logistic': array([0.12262997], dtype=float32),
#   'probabilities': array([0.8773701 , 0.12262996], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.28444624], dtype=float32),
#   'logistic': array([0.5706359], dtype=float32),
#   'probabilities': array([0.42936406, 0.5706359 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.4194589], dtype=float32),
#   'logistic': array([0.91829914], dtype=float32),
#   'probabilities': array([0.08170084, 0.9182992 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5406917], dtype=float32),
#   'logistic': array([0.3680267], dtype=float32),
#   'probabilities': array([0.6319733 , 0.36802667], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.81491053], dtype=float32),
#   'logistic': array([0.3068451], dtype=float32),
#   'probabilities': array([0.69315493, 0.30684507], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.20745242], dtype=float32),
#   'logistic': array([0.5516779], dtype=float32),
#   'probabilities': array([0.44832206, 0.5516779 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0313236], dtype=float32),
#   'logistic': array([0.26282758], dtype=float32),
#   'probabilities': array([0.73717237, 0.26282758], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.39613038], dtype=float32),
#   'logistic': array([0.40224242], dtype=float32),
#   'probabilities': array([0.5977576 , 0.40224242], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.00783622], dtype=float32),
#   'logistic': array([0.49804094], dtype=float32),
#   'probabilities': array([0.501959  , 0.49804094], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4863484], dtype=float32),
#   'logistic': array([0.6192458], dtype=float32),
#   'probabilities': array([0.38075414, 0.6192458 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1298234], dtype=float32),
#   'logistic': array([0.7558063], dtype=float32),
#   'probabilities': array([0.24419366, 0.7558063 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8045461], dtype=float32),
#   'logistic': array([0.3090539], dtype=float32),
#   'probabilities': array([0.6909461 , 0.30905387], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4717345], dtype=float32),
#   'logistic': array([0.18667912], dtype=float32),
#   'probabilities': array([0.81332093, 0.18667911], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.17240667], dtype=float32),
#   'logistic': array([0.5429952], dtype=float32),
#   'probabilities': array([0.4570048, 0.5429953], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5681801], dtype=float32),
#   'logistic': array([0.172476], dtype=float32),
#   'probabilities': array([0.827524  , 0.17247596], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.03904879], dtype=float32),
#   'logistic': array([0.509761], dtype=float32),
#   'probabilities': array([0.49023905, 0.509761  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6587744], dtype=float32),
#   'logistic': array([0.1599266], dtype=float32),
#   'probabilities': array([0.8400734, 0.1599266], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9199574], dtype=float32),
#   'logistic': array([0.1278663], dtype=float32),
#   'probabilities': array([0.8721337, 0.1278663], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2819376], dtype=float32),
#   'logistic': array([0.57002115], dtype=float32),
#   'probabilities': array([0.4299788 , 0.57002115], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5796802], dtype=float32),
#   'logistic': array([0.17084077], dtype=float32),
#   'probabilities': array([0.82915926, 0.17084076], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3132795], dtype=float32),
#   'logistic': array([0.21193859], dtype=float32),
#   'probabilities': array([0.78806144, 0.21193856], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6655966], dtype=float32),
#   'logistic': array([0.15901215], dtype=float32),
#   'probabilities': array([0.84098786, 0.15901214], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5920106], dtype=float32),
#   'logistic': array([0.16910121], dtype=float32),
#   'probabilities': array([0.8308988 , 0.16910118], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0898203], dtype=float32),
#   'logistic': array([0.25165218], dtype=float32),
#   'probabilities': array([0.7483479 , 0.25165212], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1083916], dtype=float32),
#   'logistic': array([0.24817085], dtype=float32),
#   'probabilities': array([0.7518292 , 0.24817085], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6041525], dtype=float32),
#   'logistic': array([0.35339424], dtype=float32),
#   'probabilities': array([0.64660573, 0.3533942 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.796456], dtype=float32),
#   'logistic': array([0.142283], dtype=float32),
#   'probabilities': array([0.857717  , 0.14228301], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2915384], dtype=float32),
#   'logistic': array([0.21559253], dtype=float32),
#   'probabilities': array([0.7844075 , 0.21559253], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4367764], dtype=float32),
#   'logistic': array([0.19204503], dtype=float32),
#   'probabilities': array([0.807955  , 0.19204505], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2370032], dtype=float32),
#   'logistic': array([0.22495806], dtype=float32),
#   'probabilities': array([0.77504194, 0.22495802], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.03633189], dtype=float32),
#   'logistic': array([0.49091804], dtype=float32),
#   'probabilities': array([0.50908196, 0.490918  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6743658], dtype=float32),
#   'logistic': array([0.15784298], dtype=float32),
#   'probabilities': array([0.84215707, 0.157843  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1585386], dtype=float32),
#   'logistic': array([0.23893294], dtype=float32),
#   'probabilities': array([0.7610671 , 0.23893292], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.45024025], dtype=float32),
#   'logistic': array([0.6106964], dtype=float32),
#   'probabilities': array([0.38930365, 0.6106964 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.48681533], dtype=float32),
#   'logistic': array([0.6193559], dtype=float32),
#   'probabilities': array([0.38064405, 0.6193559 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.06339741], dtype=float32),
#   'logistic': array([0.51584405], dtype=float32),
#   'probabilities': array([0.48415595, 0.51584405], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6329367], dtype=float32),
#   'logistic': array([0.34684497], dtype=float32),
#   'probabilities': array([0.653155 , 0.3468449], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.11504614], dtype=float32),
#   'logistic': array([0.47127014], dtype=float32),
#   'probabilities': array([0.5287299 , 0.47127014], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3876235], dtype=float32),
#   'logistic': array([0.19978744], dtype=float32),
#   'probabilities': array([0.80021256, 0.19978741], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2891825], dtype=float32),
#   'logistic': array([0.21599123], dtype=float32),
#   'probabilities': array([0.78400886, 0.21599121], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6625938], dtype=float32),
#   'logistic': array([0.15941411], dtype=float32),
#   'probabilities': array([0.8405859 , 0.15941411], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8029101], dtype=float32),
#   'logistic': array([0.1414972], dtype=float32),
#   'probabilities': array([0.85850286, 0.1414972 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.42218113], dtype=float32),
#   'logistic': array([0.60400504], dtype=float32),
#   'probabilities': array([0.39599493, 0.60400504], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0770711], dtype=float32),
#   'logistic': array([0.2540607], dtype=float32),
#   'probabilities': array([0.7459393, 0.2540607], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.42461985], dtype=float32),
#   'logistic': array([0.3954118], dtype=float32),
#   'probabilities': array([0.6045882, 0.3954118], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.18045413], dtype=float32),
#   'logistic': array([0.5449915], dtype=float32),
#   'probabilities': array([0.45500848, 0.54499155], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7483347], dtype=float32),
#   'logistic': array([0.32118428], dtype=float32),
#   'probabilities': array([0.67881566, 0.32118425], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3926456], dtype=float32),
#   'logistic': array([0.5969194], dtype=float32),
#   'probabilities': array([0.4030806, 0.5969194], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9369631], dtype=float32),
#   'logistic': array([0.12598187], dtype=float32),
#   'probabilities': array([0.87401813, 0.12598185], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4590416], dtype=float32),
#   'logistic': array([0.61278677], dtype=float32),
#   'probabilities': array([0.38721317, 0.61278677], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8100214], dtype=float32),
#   'logistic': array([0.14063554], dtype=float32),
#   'probabilities': array([0.8593645 , 0.14063554], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.1788863], dtype=float32),
#   'logistic': array([0.5446027], dtype=float32),
#   'probabilities': array([0.45539728, 0.54460275], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.62797296], dtype=float32),
#   'logistic': array([0.3479703], dtype=float32),
#   'probabilities': array([0.6520297, 0.3479703], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4891607], dtype=float32),
#   'logistic': array([0.18404773], dtype=float32),
#   'probabilities': array([0.8159523 , 0.18404773], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.21565807], dtype=float32),
#   'logistic': array([0.5537065], dtype=float32),
#   'probabilities': array([0.4462934, 0.5537065], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.19865298], dtype=float32),
#   'logistic': array([0.5495006], dtype=float32),
#   'probabilities': array([0.4504994, 0.5495006], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.16409373], dtype=float32),
#   'logistic': array([0.54093164], dtype=float32),
#   'probabilities': array([0.45906833, 0.54093164], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5417609], dtype=float32),
#   'logistic': array([0.1762794], dtype=float32),
#   'probabilities': array([0.82372063, 0.17627943], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4351368], dtype=float32),
#   'logistic': array([0.3929004], dtype=float32),
#   'probabilities': array([0.60709965, 0.39290038], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6474167], dtype=float32),
#   'logistic': array([0.16145834], dtype=float32),
#   'probabilities': array([0.8385416, 0.1614584], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8586583], dtype=float32),
#   'logistic': array([0.70238024], dtype=float32),
#   'probabilities': array([0.2976197 , 0.70238024], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.4225512], dtype=float32),
#   'logistic': array([0.80573803], dtype=float32),
#   'probabilities': array([0.19426195, 0.8057381 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.34171104], dtype=float32),
#   'logistic': array([0.58460605], dtype=float32),
#   'probabilities': array([0.4153939, 0.5846061], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3786095], dtype=float32),
#   'logistic': array([0.20123243], dtype=float32),
#   'probabilities': array([0.79876757, 0.20123239], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.09264481], dtype=float32),
#   'logistic': array([0.47685534], dtype=float32),
#   'probabilities': array([0.52314466, 0.47685534], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.62688494], dtype=float32),
#   'logistic': array([0.34821725], dtype=float32),
#   'probabilities': array([0.6517828, 0.3482172], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.13779616], dtype=float32),
#   'logistic': array([0.46560538], dtype=float32),
#   'probabilities': array([0.5343947 , 0.46560535], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5820298], dtype=float32),
#   'logistic': array([0.35846567], dtype=float32),
#   'probabilities': array([0.6415343 , 0.35846564], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.24505424], dtype=float32),
#   'logistic': array([0.4390412], dtype=float32),
#   'probabilities': array([0.5609588 , 0.43904117], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5654703], dtype=float32),
#   'logistic': array([0.17286307], dtype=float32),
#   'probabilities': array([0.82713693, 0.17286307], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.23284996], dtype=float32),
#   'logistic': array([0.5579509], dtype=float32),
#   'probabilities': array([0.4420491, 0.5579509], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.11896145], dtype=float32),
#   'logistic': array([0.52970535], dtype=float32),
#   'probabilities': array([0.4702946 , 0.52970535], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2293291], dtype=float32),
#   'logistic': array([0.22629884], dtype=float32),
#   'probabilities': array([0.7737012 , 0.22629884], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4091378], dtype=float32),
#   'logistic': array([0.19637007], dtype=float32),
#   'probabilities': array([0.80362993, 0.19637007], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5390502], dtype=float32),
#   'logistic': array([0.17667341], dtype=float32),
#   'probabilities': array([0.82332665, 0.17667337], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0583969], dtype=float32),
#   'logistic': array([0.25761592], dtype=float32),
#   'probabilities': array([0.7423841, 0.2576159], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5336933], dtype=float32),
#   'logistic': array([0.3696559], dtype=float32),
#   'probabilities': array([0.6303441 , 0.36965585], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7023602], dtype=float32),
#   'logistic': array([0.15415728], dtype=float32),
#   'probabilities': array([0.8458428 , 0.15415728], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.85488725], dtype=float32),
#   'logistic': array([0.29840863], dtype=float32),
#   'probabilities': array([0.7015914 , 0.29840863], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2248143], dtype=float32),
#   'logistic': array([0.22709036], dtype=float32),
#   'probabilities': array([0.7729097, 0.2270903], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1132088], dtype=float32),
#   'logistic': array([0.10781961], dtype=float32),
#   'probabilities': array([0.8921804 , 0.10781961], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7787688], dtype=float32),
#   'logistic': array([0.14445524], dtype=float32),
#   'probabilities': array([0.8555448 , 0.14445522], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.9135709], dtype=float32),
#   'logistic': array([0.71373034], dtype=float32),
#   'probabilities': array([0.28626966, 0.71373034], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4630383], dtype=float32),
#   'logistic': array([0.18800306], dtype=float32),
#   'probabilities': array([0.811997  , 0.18800306], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.72195], dtype=float32),
#   'logistic': array([0.15162015], dtype=float32),
#   'probabilities': array([0.8483799 , 0.15162016], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6195505], dtype=float32),
#   'logistic': array([0.16526687], dtype=float32),
#   'probabilities': array([0.8347332 , 0.16526687], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.07136834], dtype=float32),
#   'logistic': array([0.4821655], dtype=float32),
#   'probabilities': array([0.51783454, 0.4821655 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.29164416], dtype=float32),
#   'logistic': array([0.4276014], dtype=float32),
#   'probabilities': array([0.5723986 , 0.42760143], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0963433], dtype=float32),
#   'logistic': array([0.2504257], dtype=float32),
#   'probabilities': array([0.7495743 , 0.25042567], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.39611644], dtype=float32),
#   'logistic': array([0.40224576], dtype=float32),
#   'probabilities': array([0.59775424, 0.40224576], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3392285], dtype=float32),
#   'logistic': array([0.20763697], dtype=float32),
#   'probabilities': array([0.7923631 , 0.20763695], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2691149], dtype=float32),
#   'logistic': array([0.21940881], dtype=float32),
#   'probabilities': array([0.7805912 , 0.21940878], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.03530371], dtype=float32),
#   'logistic': array([0.491175], dtype=float32),
#   'probabilities': array([0.508825  , 0.49117497], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.04707611], dtype=float32),
#   'logistic': array([0.48823315], dtype=float32),
#   'probabilities': array([0.51176685, 0.48823315], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7219695], dtype=float32),
#   'logistic': array([0.15161765], dtype=float32),
#   'probabilities': array([0.8483824 , 0.15161766], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.51413226], dtype=float32),
#   'logistic': array([0.37422532], dtype=float32),
#   'probabilities': array([0.6257747, 0.3742253], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.67360926], dtype=float32),
#   'logistic': array([0.66231084], dtype=float32),
#   'probabilities': array([0.33768913, 0.6623108 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.08005917], dtype=float32),
#   'logistic': array([0.5200041], dtype=float32),
#   'probabilities': array([0.4799959 , 0.52000415], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.45857948], dtype=float32),
#   'logistic': array([0.38732287], dtype=float32),
#   'probabilities': array([0.61267716, 0.38732284], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2302661], dtype=float32),
#   'logistic': array([0.5573135], dtype=float32),
#   'probabilities': array([0.44268647, 0.5573135 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2545649], dtype=float32),
#   'logistic': array([0.22191094], dtype=float32),
#   'probabilities': array([0.7780891 , 0.22191091], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3362916], dtype=float32),
#   'logistic': array([0.20812058], dtype=float32),
#   'probabilities': array([0.7918794 , 0.20812057], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7196434], dtype=float32),
#   'logistic': array([0.15191707], dtype=float32),
#   'probabilities': array([0.8480829, 0.1519171], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9497397], dtype=float32),
#   'logistic': array([0.27893722], dtype=float32),
#   'probabilities': array([0.7210628 , 0.27893716], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.02002895], dtype=float32),
#   'logistic': array([0.49499294], dtype=float32),
#   'probabilities': array([0.5050071 , 0.49499294], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7155051], dtype=float32),
#   'logistic': array([0.67161644], dtype=float32),
#   'probabilities': array([0.32838356, 0.67161644], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1317483], dtype=float32),
#   'logistic': array([0.24383858], dtype=float32),
#   'probabilities': array([0.75616145, 0.24383858], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5262499], dtype=float32),
#   'logistic': array([0.17854303], dtype=float32),
#   'probabilities': array([0.821457  , 0.17854302], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5143367], dtype=float32),
#   'logistic': array([0.37417746], dtype=float32),
#   'probabilities': array([0.62582254, 0.37417743], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1638621], dtype=float32),
#   'logistic': array([0.23796624], dtype=float32),
#   'probabilities': array([0.7620338 , 0.23796621], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6786238], dtype=float32),
#   'logistic': array([0.15727778], dtype=float32),
#   'probabilities': array([0.8427223 , 0.15727781], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5238184], dtype=float32),
#   'logistic': array([0.17889994], dtype=float32),
#   'probabilities': array([0.8211001 , 0.17889991], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7739222], dtype=float32),
#   'logistic': array([0.14505526], dtype=float32),
#   'probabilities': array([0.8549448 , 0.14505525], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4476086], dtype=float32),
#   'logistic': array([0.3899295], dtype=float32),
#   'probabilities': array([0.6100705, 0.3899295], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.9872949], dtype=float32),
#   'logistic': array([0.7285533], dtype=float32),
#   'probabilities': array([0.27144673, 0.72855324], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
# ...
#   'logistic': array([0.7224138], dtype=float32),
#   'probabilities': array([0.2775862 , 0.72241384], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.714726], dtype=float32),
#   'logistic': array([0.15255174], dtype=float32),
#   'probabilities': array([0.8474483 , 0.15255174], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7261366], dtype=float32),
#   'logistic': array([0.15108243], dtype=float32),
#   'probabilities': array([0.8489176 , 0.15108241], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1914904], dtype=float32),
#   'logistic': array([0.23299247], dtype=float32),
#   'probabilities': array([0.7670076 , 0.23299247], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.79808503], dtype=float32),
#   'logistic': array([0.3104353], dtype=float32),
#   'probabilities': array([0.6895647 , 0.31043527], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.53597754], dtype=float32),
#   'logistic': array([0.36912382], dtype=float32),
#   'probabilities': array([0.63087624, 0.36912376], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.21206093], dtype=float32),
#   'logistic': array([0.55281746], dtype=float32),
#   'probabilities': array([0.44718254, 0.55281746], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.20263219], dtype=float32),
#   'logistic': array([0.55048543], dtype=float32),
#   'probabilities': array([0.44951454, 0.55048543], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.46235502], dtype=float32),
#   'logistic': array([0.3864273], dtype=float32),
#   'probabilities': array([0.6135727 , 0.38642725], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.56343275], dtype=float32),
#   'logistic': array([0.36275357], dtype=float32),
#   'probabilities': array([0.63724643, 0.3627535 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.70871073], dtype=float32),
#   'logistic': array([0.3298838], dtype=float32),
#   'probabilities': array([0.67011625, 0.3298838 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5000594], dtype=float32),
#   'logistic': array([0.18241668], dtype=float32),
#   'probabilities': array([0.8175834 , 0.18241666], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5221082], dtype=float32),
#   'logistic': array([0.6276406], dtype=float32),
#   'probabilities': array([0.37235937, 0.6276406 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7430174], dtype=float32),
#   'logistic': array([0.14893007], dtype=float32),
#   'probabilities': array([0.8510699 , 0.14893004], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1497731], dtype=float32),
#   'logistic': array([0.24053058], dtype=float32),
#   'probabilities': array([0.7594695, 0.2405305], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.26018345], dtype=float32),
#   'logistic': array([0.5646814], dtype=float32),
#   'probabilities': array([0.43531862, 0.5646814 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.57324314], dtype=float32),
#   'logistic': array([0.36048883], dtype=float32),
#   'probabilities': array([0.63951117, 0.3604888 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4597998], dtype=float32),
#   'logistic': array([0.18849796], dtype=float32),
#   'probabilities': array([0.8115021 , 0.18849796], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.85197175], dtype=float32),
#   'logistic': array([0.2990194], dtype=float32),
#   'probabilities': array([0.7009806 , 0.29901937], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0965322], dtype=float32),
#   'logistic': array([0.25039023], dtype=float32),
#   'probabilities': array([0.74960977, 0.2503902 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7285125], dtype=float32),
#   'logistic': array([0.15077794], dtype=float32),
#   'probabilities': array([0.8492221 , 0.15077794], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1903021], dtype=float32),
#   'logistic': array([0.23320487], dtype=float32),
#   'probabilities': array([0.76679516, 0.23320489], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.18962336], dtype=float32),
#   'logistic': array([0.5472643], dtype=float32),
#   'probabilities': array([0.45273566, 0.54726434], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7327602], dtype=float32),
#   'logistic': array([0.6754107], dtype=float32),
#   'probabilities': array([0.3245893, 0.6754107], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.43854964], dtype=float32),
#   'logistic': array([0.6079134], dtype=float32),
#   'probabilities': array([0.39208657, 0.6079134 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7968912], dtype=float32),
#   'logistic': array([0.6893091], dtype=float32),
#   'probabilities': array([0.31069088, 0.68930906], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.45735526], dtype=float32),
#   'logistic': array([0.38761342], dtype=float32),
#   'probabilities': array([0.6123866, 0.3876134], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.82707083], dtype=float32),
#   'logistic': array([0.30426478], dtype=float32),
#   'probabilities': array([0.6957352 , 0.30426475], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.0178684], dtype=float32),
#   'logistic': array([0.50446695], dtype=float32),
#   'probabilities': array([0.49553305, 0.504467  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3465879], dtype=float32),
#   'logistic': array([0.20642877], dtype=float32),
#   'probabilities': array([0.79357123, 0.20642877], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5467288], dtype=float32),
#   'logistic': array([0.17555925], dtype=float32),
#   'probabilities': array([0.8244408 , 0.17555921], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4252958], dtype=float32),
#   'logistic': array([0.19383273], dtype=float32),
#   'probabilities': array([0.8061673, 0.1938327], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.09385848], dtype=float32),
#   'logistic': array([0.4765526], dtype=float32),
#   'probabilities': array([0.5234474 , 0.47655255], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.6472704], dtype=float32),
#   'logistic': array([0.06615743], dtype=float32),
#   'probabilities': array([0.9338426 , 0.06615744], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9391836], dtype=float32),
#   'logistic': array([0.28106532], dtype=float32),
#   'probabilities': array([0.7189347, 0.2810653], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.607111], dtype=float32),
#   'logistic': array([0.1669901], dtype=float32),
#   'probabilities': array([0.83300996, 0.1669901 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1300651], dtype=float32),
#   'logistic': array([0.24414909], dtype=float32),
#   'probabilities': array([0.755851  , 0.24414907], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0182643], dtype=float32),
#   'logistic': array([0.26536563], dtype=float32),
#   'probabilities': array([0.73463434, 0.26536563], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8689686], dtype=float32),
#   'logistic': array([0.295469], dtype=float32),
#   'probabilities': array([0.704531 , 0.2954689], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2104335], dtype=float32),
#   'logistic': array([0.7703756], dtype=float32),
#   'probabilities': array([0.22962433, 0.77037567], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4030097], dtype=float32),
#   'logistic': array([0.19733897], dtype=float32),
#   'probabilities': array([0.80266106, 0.19733897], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7760489], dtype=float32),
#   'logistic': array([0.14479172], dtype=float32),
#   'probabilities': array([0.85520834, 0.1447917 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3153653], dtype=float32),
#   'logistic': array([0.5781943], dtype=float32),
#   'probabilities': array([0.42180568, 0.5781943 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.27233756], dtype=float32),
#   'logistic': array([0.43233332], dtype=float32),
#   'probabilities': array([0.56766665, 0.4323333 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.703227], dtype=float32),
#   'logistic': array([0.8459557], dtype=float32),
#   'probabilities': array([0.15404427, 0.8459558 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.40982044], dtype=float32),
#   'logistic': array([0.6010448], dtype=float32),
#   'probabilities': array([0.39895517, 0.60104483], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7770954], dtype=float32),
#   'logistic': array([0.14466216], dtype=float32),
#   'probabilities': array([0.8553379 , 0.14466217], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.34921646], dtype=float32),
#   'logistic': array([0.58642757], dtype=float32),
#   'probabilities': array([0.41357243, 0.5864276 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)}]
